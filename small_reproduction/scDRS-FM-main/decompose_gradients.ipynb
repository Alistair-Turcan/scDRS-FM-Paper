# %% [markdown]
# # Decompose Gradients Notebook
# Notebook counterpart to `decompose_gradients.py`.

# %%
from scdrs_fm.decompose_gradients import run_decomposition

# %%
# --- user inputs ---
adata_file = '/path/to/input.h5ad'
trait_dir = '/path/to/trait_scores'
pheno_dir = '/path/to/pheno_scores'
out_dir = './decompose_output'
traits = ['trait1.gs']
phenotypes = ['pheno1', 'pheno2']
additional_phenotypes = []
cell_type_col = ''
cell_type = ''
n_controls = 1000

# %%
run_decomposition(
    adata_file=adata_file,
    trait_dir=trait_dir,
    pheno_dir=pheno_dir,
    out_dir=out_dir,
    traits=traits,
    phenotypes=phenotypes,
    additional_phenotypes=additional_phenotypes,
    cell_type_col=cell_type_col,
    cell_type=cell_type,
    n_controls=n_controls,
)

# %% [markdown]
# Outputs per trait:
# - `{trait}.marg-marg.decomposition.tsv.gz`
# - `{trait}.marg-cond.decomposition.tsv.gz`
# - `{trait}.cond-cond.decomposition.tsv.gz`
